# %% [markdown]
# # EDA Template - Triage AI
#
# Khám phá dữ liệu trước khi huấn luyện.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/processed/dataset_final.csv')
df.head()

# %%
df.describe()

# %%
sns.countplot(data=df, x='triage_level')
plt.title('Phân bố mức độ ưu tiên')
plt.show()
